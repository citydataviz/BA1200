# %% [markdown]
# # 1) Import three dataset (Dognition data: test_info + dog_info + membership_info)
# - files: https://github.com/citydataviz/BA1200/tree/main/Coursework1_group

# %%
import pandas as pd

df1 = pd.read_csv('/Users/adfz088/Documents/GitHub/BA1200/Coursework1_group/test_info.csv')
df2 = pd.read_csv('/Users/adfz088/Documents/GitHub/BA1200/Coursework1_group/dog_info.csv')
df3 = pd.read_csv('/Users/adfz088/Documents/GitHub/BA1200/Coursework1_group/membership_info.csv')

merge_df = pd.merge(df1, df2, on='Dog ID', how = 'inner')
final_df = pd.merge(merge_df, df3, on = 'User ID', how = 'left')

# %%
# Out:
#        Unnamed: 0                                Dog ID  \
# 0               0  fd27b272-7144-11e5-ba71-058fbc01cf0b
# 1               1  fd27b5ba-7144-11e5-ba71-058fbc01cf0b
# 2               2  fd27b6b4-7144-11e5-ba71-058fbc01cf0b
# 3               3  fd27b79a-7144-11e5-ba71-058fbc01cf0b
# 4               4  fd27b86c-7144-11e5-ba71-058fbc01cf0b
# ...           ...                                   ...
# 17981       17981  fdc235e0-7144-11e5-ba71-058fbc01cf0b
# 17982       17982  fdc23a68-7144-11e5-ba71-058fbc01cf0b
# 17983       17983  fdc23ba8-7144-11e5-ba71-058fbc01cf0b
# 17984       17984  fdc23e96-7144-11e5-ba71-058fbc01cf0b
# 17985       17985  fdc2417a-7144-11e5-ba71-058fbc01cf0b
#
#        Total Tests Completed  Mean ITI (days)  Mean ITI (minutes)  \
# 0                         21        28.201076        40609.549167
# 1                         20         0.413307          595.162281
# 2                          2         0.009132           13.150000
# 3                         11        56.115179        80805.858333
# 4                         31         7.734254        11137.326111
# ...                      ...              ...                 ...
# 17981                      7         0.009408           13.547222
# 17982                      1              NaN                 NaN
# 17983                     20         0.004957            7.137719
# 17984                      4         0.002948            4.244444
# 17985                      6         0.004012            5.776667
#
#        Median ITI (days)  Median ITI (minutes)  \
# 0               0.004687              6.750000
# 1               0.005845              8.416667
# 2               0.009132             13.150000
# 3               0.004433              6.383333
# 4               0.000399              0.575000
# ...                  ...                   ...
# 17981           0.004786              6.891667
# 17982                NaN                   NaN
# 17983           0.004201              6.050000
# 17984           0.002778              4.000000
# 17985           0.003032              4.366667
#
#        Time diff between first and last game (days)  \
# 0                                        564.021516
# 1                                          7.852836
# 2                                          0.009132
# 3                                        561.151794
# 4                                        232.027627
# ...                                             ...
# 17981                                      0.056447
# 17982                                      0.000000
# 17983                                      0.094178
# 17984                                      0.008843
# 17985                                      0.020058
#
#        Time diff between first and last game (minutes)
# 0                                        812190.983333
# 1                                         11308.083333
# 2                                            13.150000
# 3                                        808058.583333
# 4                                        334119.783333
# ...                                                ...
# 17981                                        81.283333
# 17982                                         0.000000
# 17983                                       135.616667
# 17984                                        12.733333
# 17985                                        28.883333
#
# [17986 rows x 9 columns]

# %% [markdown]
# # 2) Merge three dataset together (using merge)
# - consider 'inner', 'left' ,' right' , 'outer'
# - check null value in 'Dog ID' or 'User ID'

# %%
df3[df3['User ID'].isnull()]
# Out:
#        Unnamed: 0 User ID  Max_Dogs  Membership_ID  Subscribed City State  \
# 14986       16643     NaN       NaN            NaN         NaN  NaN   NaN
#
#       Country Exclude Free_Start_User Last_Active_At Membership_Type
# 14986     NaN     NaN             NaN            NaN             NaN

# %% [markdown]
# # 3) How many unique human user IDs are there in the aggregated data set?

# %%
len(final_df)
# Out:
# 17986

# %%
final_df['User ID'].nunique()
# Out:
# 16261

# %% [markdown]
# # 4) What feature is common to all the rows that have a value of 37 in the “State” field of the aggregated data set?

# %%
final_df[final_df["State"] == "37"].T
# Out:
#                                                                                 398    \
# Unnamed: 0_x                                                                      398
# Dog ID                                           fd40fa66-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                              20
# Mean ITI (days)                                                               0.01126
# Mean ITI (minutes)                                                          16.214035
# Median ITI (days)                                                            0.006331
# Median ITI (minutes)                                                         9.116667
# Time diff between first and last game (days)                                 0.213935
# Time diff between first and last game (minutes)                            308.066667
# Unnamed: 0_y                                                                      398
# User ID                                          ce137bce-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                         female
# Birthday                                                                       2011.0
# Breed                                                                       Dachshund
# Breed_Type                                                                 Pure Breed
# Breed_Group                                                                     Hound
# Weight                                                                            0.0
# Dog_Fixed                                                                         0.0
# DNA_Tested                                                                        0.0
# Dimension                                                             renaissance-dog
# Sign_in_Count                                                                    14.0
# Unnamed: 0                                                                        398
# Max_Dogs                                                                          1.0
# Membership_ID                                                                     1.0
# Subscribed                                                                        1.0
# City                                                                          Tallinn
# State                                                                              37
# Country                                                                            EE
# Exclude                                                                             0
# Free_Start_User                                                                     0
# Last_Active_At                                                          6/27/14 14:45
# Membership_Type                                                                     1
#
#                                                                                 5399   \
# Unnamed: 0_x                                                                     5399
# Dog ID                                           fd674df6-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                              31
# Mean ITI (days)                                                              8.002653
# Mean ITI (minutes)                                                           11523.82
# Median ITI (days)                                                            0.004028
# Median ITI (minutes)                                                              5.8
# Time diff between first and last game (days)                               240.079583
# Time diff between first and last game (minutes)                              345714.6
# Unnamed: 0_y                                                                     5399
# User ID                                          ce415c56-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                           male
# Birthday                                                                       2011.0
# Breed                                                             Miniature Schnauzer
# Breed_Type                                                                 Pure Breed
# Breed_Group                                                                   Terrier
# Weight                                                                           10.0
# Dog_Fixed                                                                         0.0
# DNA_Tested                                                                        0.0
# Dimension                                                                      expert
# Sign_in_Count                                                                    13.0
# Unnamed: 0                                                                       5399
# Max_Dogs                                                                          1.0
# Membership_ID                                                                     3.0
# Subscribed                                                                        1.0
# City                                                                          Tallinn
# State                                                                              37
# Country                                                                            EE
# Exclude                                                                             0
# Free_Start_User                                                                     1
# Last_Active_At                                                            8/3/15 5:50
# Membership_Type                                                                     3
#
#                                                                                 11208  \
# Unnamed: 0_x                                                                    11208
# Dog ID                                           fd7c19fc-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                               2
# Mean ITI (days)                                                              0.002708
# Mean ITI (minutes)                                                                3.9
# Median ITI (days)                                                            0.002708
# Median ITI (minutes)                                                              3.9
# Time diff between first and last game (days)                                 0.002708
# Time diff between first and last game (minutes)                                   3.9
# Unnamed: 0_y                                                                    11208
# User ID                                          ce7b84b2-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                         female
# Birthday                                                                       2015.0
# Breed                                                                     St. Bernard
# Breed_Type                                                                 Pure Breed
# Breed_Group                                                                         0
# Weight                                                                           40.0
# Dog_Fixed                                                                         0.0
# DNA_Tested                                                                        0.0
# Dimension                                                                           0
# Sign_in_Count                                                                     1.0
# Unnamed: 0                                                                      11208
# Max_Dogs                                                                          1.0
# Membership_ID                                                                    10.0
# Subscribed                                                                        1.0
# City                                                                          Tallinn
# State                                                                              37
# Country                                                                            EE
# Exclude                                                                             0
# Free_Start_User                                                                     0
# Last_Active_At                                                            5/9/15 8:02
# Membership_Type                                                                     1
#
#                                                                                 15678  \
# Unnamed: 0_x                                                                    15678
# Dog ID                                           fdb61558-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                              14
# Mean ITI (days)                                                              2.751638
# Mean ITI (minutes)                                                        3962.358974
# Median ITI (days)                                                            0.390069
# Median ITI (minutes)                                                            561.7
# Time diff between first and last game (days)                                35.771296
# Time diff between first and last game (minutes)                          51510.666667
# Unnamed: 0_y                                                                    15678
# User ID                                          ce917880-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                         female
# Birthday                                                                       2012.0
# Breed                                                                           Mixed
# Breed_Type                                           Mixed Breed/ Other/ I Don't Know
# Breed_Group                                                                         0
# Weight                                                                           50.0
# Dog_Fixed                                                                         1.0
# DNA_Tested                                                                        0.0
# Dimension                                                                           0
# Sign_in_Count                                                                     6.0
# Unnamed: 0                                                                      15678
# Max_Dogs                                                                          1.0
# Membership_ID                                                                    10.0
# Subscribed                                                                        0.0
# City                                                                     Harju County
# State                                                                              37
# Country                                                                            EE
# Exclude                                                                             0
# Free_Start_User                                                                     1
# Last_Active_At                                                          9/24/15 18:15
# Membership_Type                                                                     1
#
#                                                                                 15721  \
# Unnamed: 0_x                                                                    15721
# Dog ID                                           fdb64e7e-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                              20
# Mean ITI (days)                                                              0.367163
# Mean ITI (minutes)                                                         528.714035
# Median ITI (days)                                                            0.004144
# Median ITI (minutes)                                                         5.966667
# Time diff between first and last game (days)                                 6.976088
# Time diff between first and last game (minutes)                          10045.566667
# Unnamed: 0_y                                                                    15721
# User ID                                          ce91a206-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                           male
# Birthday                                                                       2011.0
# Breed                                                              Labrador Retriever
# Breed_Type                                                                 Pure Breed
# Breed_Group                                                                  Sporting
# Weight                                                                           10.0
# Dog_Fixed                                                                         1.0
# DNA_Tested                                                                        0.0
# Dimension                                                                     charmer
# Sign_in_Count                                                                     9.0
# Unnamed: 0                                                                      15721
# Max_Dogs                                                                          1.0
# Membership_ID                                                                    10.0
# Subscribed                                                                        1.0
# City                                                                      Viimsi Vald
# State                                                                              37
# Country                                                                            EE
# Exclude                                                                             0
# Free_Start_User                                                                     0
# Last_Active_At                                                          8/17/15 19:15
# Membership_Type                                                                     1
#
#                                                                                 15724  \
# Unnamed: 0_x                                                                    15724
# Dog ID                                           fdb653ba-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                               7
# Mean ITI (days)                                                              2.514662
# Mean ITI (minutes)                                                        3621.113889
# Median ITI (days)                                                            0.011036
# Median ITI (minutes)                                                        15.891667
# Time diff between first and last game (days)                                15.087975
# Time diff between first and last game (minutes)                          21726.683333
# Unnamed: 0_y                                                                    15724
# User ID                                          ce91a4ae-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                         female
# Birthday                                                                       2014.0
# Breed                                                             Australian Shepherd
# Breed_Type                                                                 Pure Breed
# Breed_Group                                                                   Herding
# Weight                                                                           30.0
# Dog_Fixed                                                                         0.0
# DNA_Tested                                                                        0.0
# Dimension                                                                           0
# Sign_in_Count                                                                     7.0
# Unnamed: 0                                                                      15724
# Max_Dogs                                                                          2.0
# Membership_ID                                                                    10.0
# Subscribed                                                                        0.0
# City                                                                          Tallinn
# State                                                                              37
# Country                                                                            EE
# Exclude                                                                             0
# Free_Start_User                                                                     1
# Last_Active_At                                                          9/22/15 13:42
# Membership_Type                                                                     1
#
#                                                                                 15737  \
# Unnamed: 0_x                                                                    15737
# Dog ID                                           fdb67228-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                               7
# Mean ITI (days)                                                              5.146622
# Mean ITI (minutes)                                                        7411.136111
# Median ITI (days)                                                            0.009502
# Median ITI (minutes)                                                        13.683333
# Time diff between first and last game (days)                                30.879734
# Time diff between first and last game (minutes)                          44466.816667
# Unnamed: 0_y                                                                    15737
# User ID                                          ce91bb10-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                         female
# Birthday                                                                       2012.0
# Breed                                                                           Mixed
# Breed_Type                                           Mixed Breed/ Other/ I Don't Know
# Breed_Group                                                                         0
# Weight                                                                           40.0
# Dog_Fixed                                                                         1.0
# DNA_Tested                                                                        0.0
# Dimension                                                                           0
# Sign_in_Count                                                                     4.0
# Unnamed: 0                                                                      15737
# Max_Dogs                                                                          1.0
# Membership_ID                                                                    10.0
# Subscribed                                                                        1.0
# City                                                                          Tallinn
# State                                                                              37
# Country                                                                            EE
# Exclude                                                                             0
# Free_Start_User                                                                     0
# Last_Active_At                                                          9/13/15 16:35
# Membership_Type                                                                     1
#
#                                                                                 15996  \
# Unnamed: 0_x                                                                    15996
# Dog ID                                           fdb7e716-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                              20
# Mean ITI (days)                                                              0.472172
# Mean ITI (minutes)                                                         679.927193
# Median ITI (days)                                                            0.006227
# Median ITI (minutes)                                                         8.966667
# Time diff between first and last game (days)                                 8.971262
# Time diff between first and last game (minutes)                          12918.616667
# Unnamed: 0_y                                                                    15996
# User ID                                          ce930b14-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                         female
# Birthday                                                                       2013.0
# Breed                                                                Golden Retriever
# Breed_Type                                                                 Pure Breed
# Breed_Group                                                                  Sporting
# Weight                                                                           50.0
# Dog_Fixed                                                                         0.0
# DNA_Tested                                                                        0.0
# Dimension                                                                   socialite
# Sign_in_Count                                                                     3.0
# Unnamed: 0                                                                      15996
# Max_Dogs                                                                          1.0
# Membership_ID                                                                    10.0
# Subscribed                                                                        0.0
# City                                                                          Tallinn
# State                                                                              37
# Country                                                                            EE
# Exclude                                                                             0
# Free_Start_User                                                                     0
# Last_Active_At                                                           9/7/15 18:17
# Membership_Type                                                                     1
#
#                                                                                 16090  \
# Unnamed: 0_x                                                                    16090
# Dog ID                                           fdb84d78-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                               7
# Mean ITI (days)                                                              0.952029
# Mean ITI (minutes)                                                        1370.922222
# Median ITI (days)                                                            0.010451
# Median ITI (minutes)                                                            15.05
# Time diff between first and last game (days)                                 5.712176
# Time diff between first and last game (minutes)                           8225.533333
# Unnamed: 0_y                                                                    16090
# User ID                                          ce9372ac-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                           male
# Birthday                                                                       2015.0
# Breed                                                            Pembroke Welsh Corgi
# Breed_Type                                                                 Pure Breed
# Breed_Group                                                                   Herding
# Weight                                                                           20.0
# Dog_Fixed                                                                         0.0
# DNA_Tested                                                                        0.0
# Dimension                                                                           0
# Sign_in_Count                                                                     9.0
# Unnamed: 0                                                                      16090
# Max_Dogs                                                                          1.0
# Membership_ID                                                                    10.0
# Subscribed                                                                        1.0
# City                                                                          Tallinn
# State                                                                              37
# Country                                                                            EE
# Exclude                                                                             0
# Free_Start_User                                                                     0
# Last_Active_At                                                           9/6/15 12:40
# Membership_Type                                                                     1
#
#                                                                                 16132  \
# Unnamed: 0_x                                                                    16132
# Dog ID                                           fdb893be-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                              20
# Mean ITI (days)                                                              0.003333
# Mean ITI (minutes)                                                           4.799123
# Median ITI (days)                                                            0.002894
# Median ITI (minutes)                                                         4.166667
# Time diff between first and last game (days)                                 0.063322
# Time diff between first and last game (minutes)                             91.183333
# Unnamed: 0_y                                                                    16132
# User ID                                          ce93bd48-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                           male
# Birthday                                                                       2014.0
# Breed                                                                  Siberian Husky
# Breed_Type                                                                 Pure Breed
# Breed_Group                                                                   Working
# Weight                                                                           60.0
# Dog_Fixed                                                                         0.0
# DNA_Tested                                                                        0.0
# Dimension                                                                   socialite
# Sign_in_Count                                                                     1.0
# Unnamed: 0                                                                      16132
# Max_Dogs                                                                          2.0
# Membership_ID                                                                    10.0
# Subscribed                                                                        0.0
# City                                                                            Tartu
# State                                                                              37
# Country                                                                            EE
# Exclude                                                                             0
# Free_Start_User                                                                     0
# Last_Active_At                                                           9/1/15 15:05
# Membership_Type                                                                     1
#
#                                                                                 16960
# Unnamed: 0_x                                                                    16960
# Dog ID                                           fdbdf868-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                               7
# Mean ITI (days)                                                              0.177894
# Mean ITI (minutes)                                                         256.166667
# Median ITI (days)                                                            0.004508
# Median ITI (minutes)                                                         6.491667
# Time diff between first and last game (days)                                 1.067361
# Time diff between first and last game (minutes)                                1537.0
# Unnamed: 0_y                                                                    16960
# User ID                                          ce91a4ae-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                         female
# Birthday                                                                       2007.0
# Breed                                                             Australian Shepherd
# Breed_Type                                                                 Pure Breed
# Breed_Group                                                                   Herding
# Weight                                                                           40.0
# Dog_Fixed                                                                         1.0
# DNA_Tested                                                                        0.0
# Dimension                                                                           0
# Sign_in_Count                                                                     7.0
# Unnamed: 0                                                                      15724
# Max_Dogs                                                                          2.0
# Membership_ID                                                                    10.0
# Subscribed                                                                        0.0
# City                                                                          Tallinn
# State                                                                              37
# Country                                                                            EE
# Exclude                                                                             0
# Free_Start_User                                                                     1
# Last_Active_At                                                          9/22/15 13:42
# Membership_Type                                                                     1

# %% [markdown]
# # 5) What feature is common to all the rows that have a value of 'CA' in the “Membership_Type” field of the aggregated data set?
# - write your thoughts on whether you want to keep these rows or not

# %%
final_df['Membership_Type'].value_counts()
# Out:
# Membership_Type
# 1     9129
# 4     3874
# 2     3735
# 3      659
# 0      502
# 5       46
# CA      40
# Name: count, dtype: int64

# %%
final_df[final_df['Membership_Type'] == 'CA']
# Out:
#        Unnamed: 0_x                                Dog ID  \
# 313             313  fd4060f6-7144-11e5-ba71-058fbc01cf0b
# 383             383  fd40e206-7144-11e5-ba71-058fbc01cf0b
# 712             712  fd4277a6-7144-11e5-ba71-058fbc01cf0b
# 1471           1471  fd454daa-7144-11e5-ba71-058fbc01cf0b
# 1505           1505  fd456290-7144-11e5-ba71-058fbc01cf0b
# 3163           3163  fd51c256-7144-11e5-ba71-058fbc01cf0b
# 4682           4682  fd641f82-7144-11e5-ba71-058fbc01cf0b
# 6252           6252  fd6a596a-7144-11e5-ba71-058fbc01cf0b
# 6331           6331  fd6aa294-7144-11e5-ba71-058fbc01cf0b
# 6338           6338  fd6aa550-7144-11e5-ba71-058fbc01cf0b
# 6352           6352  fd6aab18-7144-11e5-ba71-058fbc01cf0b
# 6419           6419  fd6ad58e-7144-11e5-ba71-058fbc01cf0b
# 6445           6445  fd6ae862-7144-11e5-ba71-058fbc01cf0b
# 6464           6464  fd6bd66e-7144-11e5-ba71-058fbc01cf0b
# 6490           6490  fd6be9ec-7144-11e5-ba71-058fbc01cf0b
# 6565           6565  fd6c288a-7144-11e5-ba71-058fbc01cf0b
# 6592           6592  fd6c6796-7144-11e5-ba71-058fbc01cf0b
# 6621           6621  fd6c7bfa-7144-11e5-ba71-058fbc01cf0b
# 6661           6661  fd6ca486-7144-11e5-ba71-058fbc01cf0b
# 6772           6772  fd6d1a56-7144-11e5-ba71-058fbc01cf0b
# 6796           6796  fd6d2780-7144-11e5-ba71-058fbc01cf0b
# 6883           6883  fd6d7910-7144-11e5-ba71-058fbc01cf0b
# 6929           6929  fd6d9792-7144-11e5-ba71-058fbc01cf0b
# 6934           6934  fd6da002-7144-11e5-ba71-058fbc01cf0b
# 6947           6947  fd6dbd76-7144-11e5-ba71-058fbc01cf0b
# 6949           6949  fd6dbf42-7144-11e5-ba71-058fbc01cf0b
# 6967           6967  fd6dc938-7144-11e5-ba71-058fbc01cf0b
# 7003           7003  fd6de18e-7144-11e5-ba71-058fbc01cf0b
# 7045           7045  fd6df818-7144-11e5-ba71-058fbc01cf0b
# 7092           7092  fd6e2bd0-7144-11e5-ba71-058fbc01cf0b
# 7120           7120  fd6e3ba2-7144-11e5-ba71-058fbc01cf0b
# 7138           7138  fd6e462e-7144-11e5-ba71-058fbc01cf0b
# 7179           7179  fd6e5b14-7144-11e5-ba71-058fbc01cf0b
# 7289           7289  fd6eb0aa-7144-11e5-ba71-058fbc01cf0b
# 7845           7845  fd706166-7144-11e5-ba71-058fbc01cf0b
# 8116           8116  fd713a8c-7144-11e5-ba71-058fbc01cf0b
# 8313           8313  fd71c33a-7144-11e5-ba71-058fbc01cf0b
# 9402           9402  fd75031a-7144-11e5-ba71-058fbc01cf0b
# 9645           9645  fd764b44-7144-11e5-ba71-058fbc01cf0b
# 13272         13272  fdab1d10-7144-11e5-ba71-058fbc01cf0b
#
#        Total Tests Completed  Mean ITI (days)  Mean ITI (minutes)  \
# 313                       20         0.219882          316.630702
# 383                       13        29.552486        42555.579167
# 712                        2         0.001424            2.050000
# 1471                       6        63.783586        91848.363333
# 1505                      20         0.258433          372.142982
# 3163                      10        14.117831        20329.675926
# 4682                      16         0.459559          661.764444
# 6252                       6         2.598900         3742.416667
# 6331                       7         0.007442           10.716667
# 6338                       4         3.676327         5293.911111
# 6352                      20         0.480562          692.008772
# 6419                       7         0.152276          219.277778
# 6445                      20         1.472448         2120.324561
# 6464                      11        31.201326        44929.910000
# 6490                      20         0.401698          578.444737
# 6565                       6         3.397757         4892.770000
# 6592                       4         0.002901            4.177778
# 6621                       7        10.018681        14426.900000
# 6661                      20         0.738658         1063.667544
# 6772                      16         0.268525          386.675556
# 6796                       4         1.051856         1514.672222
# 6883                      11         0.092846          133.698333
# 6929                      13         0.250557          360.801389
# 6934                       7         0.166998          240.477778
# 6947                       6         0.005863            8.443333
# 6949                      16         0.149086          214.683333
# 6967                      13        11.924569        17171.379167
# 7003                       4         0.004024            5.794444
# 7045                       7         0.842033         1212.527778
# 7092                      16         0.337824          486.466667
# 7120                      16         0.202061          290.967778
# 7138                      14         0.004470            6.437179
# 7179                       6         0.004176            6.013333
# 7289                      20         1.479202         2130.050877
# 7845                       7         0.169986          244.780556
# 8116                       4         0.004097            5.900000
# 8313                      11         0.199689          287.551667
# 9402                      20         6.319902         9100.658772
# 9645                       1              NaN                 NaN
# 13272                     11         0.905472         1303.880000
#
#        Median ITI (days)  Median ITI (minutes)  \
# 313             0.001875              2.700000
# 383             0.001418              2.041667
# 712             0.001424              2.050000
# 1471            0.017650             25.416667
# 1505            0.003183              4.583333
# 3163            0.005301              7.633333
# 4682            0.005787              8.333333
# 6252            0.006794              9.783333
# 6331            0.004537              6.533333
# 6338            0.176389            254.000000
# 6352            0.005810              8.366667
# 6419            0.004497              6.475000
# 6445            0.004792              6.900000
# 6464            0.003848              5.541667
# 6490            0.004583              6.600000
# 6565            0.007106             10.233333
# 6592            0.002685              3.866667
# 6621            0.005394              7.766667
# 6661            0.010926             15.733333
# 6772            0.004410              6.350000
# 6796            0.008912             12.833333
# 6883            0.002934              4.225000
# 6929            0.004473              6.441667
# 6934            0.003698              5.325000
# 6947            0.004595              6.616667
# 6949            0.002755              3.966667
# 6967            0.004740              6.825000
# 7003            0.002199              3.166667
# 7045            0.005434              7.825000
# 7092            0.004352              6.266667
# 7120            0.004780              6.883333
# 7138            0.002940              4.233333
# 7179            0.003472              5.000000
# 7289            0.004514              6.500000
# 7845            0.005932              8.541667
# 8116            0.003345              4.816667
# 8313            0.004537              6.533333
# 9402            0.004178              6.016667
# 9645                 NaN                   NaN
# 13272           0.004346              6.258333
#
#        Time diff between first and last game (days)  \
# 313                                        4.177766
# 383                                      354.629826
# 712                                        0.001424
# 1471                                     318.917928
# 1505                                       4.910220
# 3163                                     127.060475
# 4682                                       6.893380
# 6252                                      12.994502
# 6331                                       0.044653
# 6338                                      11.028981
# 6352                                       9.130671
# 6419                                       0.913657
# 6445                                      27.976505
# 6464                                     312.013264
# 6490                                       7.632257
# 6565                                      16.988785
# 6592                                       0.008704
# 6621                                      60.112083
# 6661                                      14.034502
# 6772                                       4.027870
# 6796                                       3.155567
# 6883                                       0.928461
# 6929                                       3.006678
# 6934                                       1.001991
# 6947                                       0.029317
# 6949                                       2.236285
# 6967                                     143.094826
# 7003                                       0.012072
# 7045                                       5.052199
# 7092                                       5.067361
# 7120                                       3.030914
# 7138                                       0.058113
# 7179                                       0.020880
# 7289                                      28.104838
# 7845                                       1.019919
# 8116                                       0.012292
# 8313                                       1.996887
# 9402                                     120.078137
# 9645                                       0.000000
# 13272                                      9.054722
#
#        Time diff between first and last game (minutes)  Unnamed: 0_y  ...  \
# 313                                        6015.983333           313  ...
# 383                                      510666.950000           383  ...
# 712                                           2.050000           712  ...
# 1471                                     459241.816667          1471  ...
# 1505                                       7070.716667          1505  ...
# 3163                                     182967.083333          3163  ...
# 4682                                       9926.466667          4682  ...
# 6252                                      18712.083333          6252  ...
# 6331                                         64.300000          6331  ...
# 6338                                      15881.733333          6338  ...
# 6352                                      13148.166667          6352  ...
# 6419                                       1315.666667          6419  ...
# 6445                                      40286.166667          6445  ...
# 6464                                     449299.100000          6464  ...
# 6490                                      10990.450000          6490  ...
# 6565                                      24463.850000          6565  ...
# 6592                                         12.533333          6592  ...
# 6621                                      86561.400000          6621  ...
# 6661                                      20209.683333          6661  ...
# 6772                                       5800.133333          6772  ...
# 6796                                       4544.016667          6796  ...
# 6883                                       1336.983333          6883  ...
# 6929                                       4329.616667          6929  ...
# 6934                                       1442.866667          6934  ...
# 6947                                         42.216667          6947  ...
# 6949                                       3220.250000          6949  ...
# 6967                                     206056.550000          6967  ...
# 7003                                         17.383333          7003  ...
# 7045                                       7275.166667          7045  ...
# 7092                                       7297.000000          7092  ...
# 7120                                       4364.516667          7120  ...
# 7138                                         83.683333          7138  ...
# 7179                                         30.066667          7179  ...
# 7289                                      40470.966667          7289  ...
# 7845                                       1468.683333          7845  ...
# 8116                                         17.700000          8116  ...
# 8313                                       2875.516667          8313  ...
# 9402                                     172912.516667          9402  ...
# 9645                                          0.000000          9645  ...
# 13272                                     13038.800000         13272  ...
#
#       Max_Dogs Membership_ID  Subscribed  \
# 313        2.0           2.0         0.0
# 383        6.0           2.0         1.0
# 712        6.0           2.0         1.0
# 1471       1.0           2.0         1.0
# 1505       1.0           1.0         1.0
# 3163       1.0           1.0         1.0
# 4682       1.0           1.0         0.0
# 6252       1.0          10.0         1.0
# 6331       1.0          10.0         1.0
# 6338       1.0          10.0         1.0
# 6352       1.0          10.0         1.0
# 6419       1.0          10.0         1.0
# 6445       1.0          10.0         1.0
# 6464       1.0          11.0         1.0
# 6490       1.0          10.0         1.0
# 6565       1.0          10.0         0.0
# 6592       1.0          10.0         1.0
# 6621       1.0          10.0         1.0
# 6661       1.0          10.0         1.0
# 6772       1.0          10.0         0.0
# 6796       2.0          11.0         1.0
# 6883       1.0          10.0         1.0
# 6929       1.0          10.0         1.0
# 6934       1.0          10.0         1.0
# 6947       1.0          10.0         1.0
# 6949       1.0          10.0         0.0
# 6967       1.0          10.0         1.0
# 7003       1.0          10.0         1.0
# 7045       1.0          10.0         1.0
# 7092       1.0          10.0         1.0
# 7120       2.0          10.0         1.0
# 7138       1.0          10.0         1.0
# 7179       1.0          10.0         1.0
# 7289       1.0          11.0         0.0
# 7845       1.0          10.0         1.0
# 8116       1.0          10.0         1.0
# 8313       1.0          10.0         0.0
# 9402       1.0          10.0         1.0
# 9645       1.0          10.0         1.0
# 13272      1.0          10.0         1.0
#
#                                          City State Country  Exclude  \
# 313                                 Thornhill    ON      CA      l4j
# 383                               Nepean East    ON      CA      K2E
# 712                               Nepean East    ON      CA      K2E
# 1471                             Bowen Island    BC      CA      V0N
# 1505                            Quinte Shores    ON      CA      K0k
# 3163                            Pender Island    BC      CA      V0N
# 4682                             Bowen Island    BC      CA      v0n
# 6252                                   Whitby    ON      CA      L1N
# 6331                            Richmond Hill    ON      CA      L4C
# 6338                              Mississauga    ON      CA      L5B
# 6352                                   London    ON      CA      N6p
# 6419                                  Toronto    ON      CA      M5A
# 6445                                   Guelph    ON      CA      N1H
# 6464                                  Toronto    ON      CA      M5a
# 6490                                  Toronto    ON      CA      M4E
# 6565                                  Toronto    ON      CA      M6K
# 6592                                 Victoria    BC      CA      V8T
# 6621                                Vancouver    BC      CA      V6B
# 6661                                Vancouver    BC      CA      V6K
# 6772                                 Pembroke    ON      CA      K8A
# 6796                       Ahuntsic Southwest    QC      CA      H3L
# 6883                                   Guelph    ON      CA      N1E
# 6929                              Scarborough    ON      CA      m1e
# 6934                                  Grimsby    ON      CA      L3M
# 6947              South Okanagan (summerland)    BC      CA      V0H
# 6949                                North Bay    ON      CA      P1B
# 6967                               Burlington    ON      CA      L7S
# 7003                                 Ancaster    ON      CA      L9G
# 7045   Georgian Bay Southwest Shore (dundalk)    ON      CA      N0C
# 7092                            Harrietsfield    NS      CA      B3V
# 7120                   Outaouais-sud (thurso)    QC      CA      J0X
# 7138                              Stouffville    ON      CA      L4A
# 7179                                  Toronto    ON      CA      M6s
# 7289                                Vancouver    BC      CA      V6N
# 7845                            Oak Bay North    BC      CA      v8r
# 8116                           Galiano Island    BC      CA      V0N
# 8313                               St. John's    NL      CA      A1B
# 9402                                   Whitby    ON      CA      L1M
# 9645                                Vancouver    BC      CA      V6K
# 13272                                Oakville    ON      CA      L6M
#
#                                          Free_Start_User  Last_Active_At  \
# 313                                       Thornhill West              ON
# 383                                          Nepean East              ON
# 712                                          Nepean East              ON
# 1471                                        North Island              BC
# 1505                                       Quinte Shores              ON
# 3163                                        North Island              BC
# 4682                                        North Island              BC
# 6252                                    Whitby Southeast              ON
# 6331                             Richmond Hill Southwest              ON
# 6338   Mississauga (West Cooksville / Fairview / City...              ON
# 6352   London (Talbot / Lambeth / West Tempo / South ...              ON
# 6419    Downtown Toronto (Regent Park / Port of Toronto)              ON
# 6445                                    Guelph Northwest              ON
# 6464    Downtown Toronto (Regent Park / Port of Toronto)              ON
# 6490                          East Toronto (The Beaches)              ON
# 6565   West Toronto (Brockton / Parkdale Village / Ex...              ON
# 6592                                      Victoria North              BC
# 6621   Vancouver (NE Downtown / Harbour Centre / Gast...              BC
# 6661                       Vancouver (Central Kitsilano)              BC
# 6772          Pembroke Central and northern subdivisions              ON
# 6796                                  Ahuntsic Southwest              QC
# 6883                                        Guelph North              ON
# 6929   Scarborough (Guildwood / Morningside / Ellesmere)              ON
# 6934                                             Grimsby              ON
# 6947                         South Okanagan (Summerland)              BC
# 6949                                   North Bay Central              ON
# 6967                                    Burlington South              ON
# 7003                                       Ancaster West              ON
# 7045              Georgian Bay Southwest Shore (Dundalk)              ON
# 7092                                       Harrietsfield              NS
# 7120                              Outaouais-Sud (Thurso)              QC
# 7138                                         Stouffville              ON
# 7179         West Toronto (Bloor West Village / Swansea)              ON
# 7289           Vancouver (Dunbar- Southlands / Musqueam)              BC
# 7845                                       Oak Bay North              BC
# 8116                                        North Island              BC
# 8313   St. John's Northwest Newfoundland & Labrador P...              NL
# 9402                                        Whitby North              ON
# 9645                       Vancouver (Central Kitsilano)              BC
# 13272                                      Oakville West              ON
#
#       Membership_Type
# 313                CA
# 383                CA
# 712                CA
# 1471               CA
# 1505               CA
# 3163               CA
# 4682               CA
# 6252               CA
# 6331               CA
# 6338               CA
# 6352               CA
# 6419               CA
# 6445               CA
# 6464               CA
# 6490               CA
# 6565               CA
# 6592               CA
# 6621               CA
# 6661               CA
# 6772               CA
# 6796               CA
# 6883               CA
# 6929               CA
# 6934               CA
# 6947               CA
# 6949               CA
# 6967               CA
# 7003               CA
# 7045               CA
# 7092               CA
# 7120               CA
# 7138               CA
# 7179               CA
# 7289               CA
# 7845               CA
# 8116               CA
# 8313               CA
# 9402               CA
# 9645               CA
# 13272              CA
#
# [40 rows x 32 columns]

# %% [markdown]
# # 6) What property is common to almost all the data points that had “Sign In Counts” of greater than 175 in the aggregated data set?

# %%
sign = final_df[final_df["Sign_in_Count"] > 175]
sign['Breed'].value_counts()
# Out:
# Breed
# Shih Tzu                             41
# Boston Terrier                        1
# Australian Shepherd                   1
# Chihuahua-Pug Mix                     1
# Golden Retriever-Basset Hound Mix     1
# German Shepherd Dog                   1
# Spinone Italiano                      1
# Golden Retriever                      1
# Rottweiler                            1
# Other                                 1
# Name: count, dtype: int64

# %% [markdown]
# # 7) what personality type has the strongest representation (greatest number of records) in the sporting breed group?

# %%
sport = final_df[final_df['Breed_Group'] == 'Sporting']
sport['Dimension'].value_counts()
# Out:
# Dimension
# 0                  1908
# socialite           195
# charmer             128
# protodog             92
# ace                  73
# renaissance-dog      67
# stargazer            48
# expert               42
# maverick             20
# einstein             14
# Name: count, dtype: int64

# %% [markdown]
# # 7) How many U.S states did customers complete a median number of tests that was greater than 13?
# - think about the difference between median and average. which one is more sensitive to extreme values?

# %%
final_df.columns
# Out:
# Index(['Unnamed: 0_x', 'Dog ID', 'Total Tests Completed', 'Mean ITI (days)',
#        'Mean ITI (minutes)', 'Median ITI (days)', 'Median ITI (minutes)',
#        'Time diff between first and last game (days)',
#        'Time diff between first and last game (minutes)', 'Unnamed: 0_y',
#        'User ID', 'Gender', 'Birthday', 'Breed', 'Breed_Type', 'Breed_Group',
#        'Weight', 'Dog_Fixed', 'DNA_Tested', 'Dimension', 'Sign_in_Count',
#        'Unnamed: 0', 'Max_Dogs', 'Membership_ID', 'Subscribed', 'City',
#        'State', 'Country', 'Exclude', 'Free_Start_User', 'Last_Active_At',
#        'Membership_Type'],
#       dtype='object')

# %%
us = final_df[final_df['Country'] == 'US']
us_median = us.groupby("State")["Total Tests Completed"].median()
us_median[us_median > 13]
# Out:
# State
# AK    15.0
# AP    13.5
# GU    20.0
# IA    15.0
# ME    18.0
# NC    14.0
# ND    19.5
# SD    20.0
# WY    15.0
# Name: Total Tests Completed, dtype: float64
