# %% [markdown]
# # Let's make another Anscombe's chart

# %% [markdown]
# - Ref: "https://www.research.autodesk.com/publications/same-stats-different-graphs/
# - video: https://youtu.be/DbJyPELmhJc?si=oN4y87b-QI6auSK6

# %% [markdown]
# # 1. Read the file 'datasaurus.csv'

# %%
import pandas as pd 

df = pd.read_csv('/Users/adfz088/Documents/GitHub/BA1200/Tutorial2/datasaurus.csv')
df.head()
# Out:
#   dataset        x        y
# 0    dino  55.3846  97.1795
# 1    dino  51.5385  96.0256
# 2    dino  46.1538  94.4872
# 3    dino  42.8205  91.4103
# 4    dino  40.7692  88.3333

# %%
df['dataset'].value_counts()
# Out:
# dataset
# dino          142
# away          142
# h_lines       142
# v_lines       142
# x_shape       142
# star          142
# high_lines    142
# dots          142
# circle        142
# bullseye      142
# slant_up      142
# slant_down    142
# wide_lines    142
# Name: count, dtype: int64

# %%
df.groupby('dataset').mean()
# Out:
#                     x          y
# dataset
# away        54.266100  47.834721
# bullseye    54.268730  47.830823
# circle      54.267320  47.837717
# dino        54.263273  47.832253
# dots        54.260303  47.839829
# h_lines     54.261442  47.830252
# high_lines  54.268805  47.835450
# slant_down  54.267849  47.835896
# slant_up    54.265882  47.831496
# star        54.267341  47.839545
# v_lines     54.269927  47.836988
# wide_lines  54.266916  47.831602
# x_shape     54.260150  47.839717

# %% [markdown]
# # 2. How many rows of the dataset?

# %%
len(df)
# Out:
# 1846

# %%
df.head()
# Out:
#   dataset        x        y
# 0    dino  55.3846  97.1795
# 1    dino  51.5385  96.0256
# 2    dino  46.1538  94.4872
# 3    dino  42.8205  91.4103
# 4    dino  40.7692  88.3333

# %% [markdown]
# # 3. How many values of each category in a column 'dataset'?

# %%
df['dataset'].value_counts()
# Out:
# dataset
# dino          142
# away          142
# h_lines       142
# v_lines       142
# x_shape       142
# star          142
# high_lines    142
# dots          142
# circle        142
# bullseye      142
# slant_up      142
# slant_down    142
# wide_lines    142
# Name: count, dtype: int64

# %% [markdown]
# # 4. what's the mean of each category in a column 'dataset'?

# %%
df.groupby('dataset').mean()
# Out:
#                     x          y
# dataset
# away        54.266100  47.834721
# bullseye    54.268730  47.830823
# circle      54.267320  47.837717
# dino        54.263273  47.832253
# dots        54.260303  47.839829
# h_lines     54.261442  47.830252
# high_lines  54.268805  47.835450
# slant_down  54.267849  47.835896
# slant_up    54.265882  47.831496
# star        54.267341  47.839545
# v_lines     54.269927  47.836988
# wide_lines  54.266916  47.831602
# x_shape     54.260150  47.839717

# %% [markdown]
# # 5. draw a scatter plot for 'dino' in a column 'dataset'

# %%
dino = df[df['dataset']=='dino']

# %%
dino
# Out:
#     dataset        x        y
# 0      dino  55.3846  97.1795
# 1      dino  51.5385  96.0256
# 2      dino  46.1538  94.4872
# 3      dino  42.8205  91.4103
# 4      dino  40.7692  88.3333
# ..      ...      ...      ...
# 137    dino  39.4872  25.3846
# 138    dino  91.2821  41.5385
# 139    dino  50.0000  95.7692
# 140    dino  47.9487  95.0000
# 141    dino  44.1026  92.6923
#
# [142 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.scatter(dino['x'], dino['y'])
plt.title('Scatter plot for Dino')
# Out:
# Text(0.5, 1.0, 'Scatter plot for Dino')

# %% [markdown]
# # 6. Add mean, var, std of x and y to the plot above
# - xlabel, ylabel
# - title
# - legend

# %%
mean_x, var_x, std_x = dino['x'].mean(), dino['x'].var(), dino['x'].std()
mean_y,var_y, std_y = dino['y'].mean(), dino['y'].var(), dino['y'].std()

# %%
plt.figure(figsize=(6,4))
plt.scatter(dino['x'], dino['y'])
plt.title('Scatter plot for Dino')
legend_text = (f'Mean x:{mean_x:.2f}')
plt.legend([legend_text])

# %% [markdown]
# # 7. Plot all scatterplots for each category in a 'dataset' column (using FOR loop)
# - Recycle the code above

# %%
dino
# Out:
#     dataset        x        y
# 0      dino  55.3846  97.1795
# 1      dino  51.5385  96.0256
# 2      dino  46.1538  94.4872
# 3      dino  42.8205  91.4103
# 4      dino  40.7692  88.3333
# ..      ...      ...      ...
# 137    dino  39.4872  25.3846
# 138    dino  91.2821  41.5385
# 139    dino  50.0000  95.7692
# 140    dino  47.9487  95.0000
# 141    dino  44.1026  92.6923
#
# [142 rows x 3 columns]

# %%
for name, group in df.groupby('dataset'): 
    print(group)
# Out:
#     dataset          x          y
# 142    away  32.331110  61.411101
# 143    away  53.421463  26.186880
# 144    away  63.920202  30.832194
# 145    away  70.289506  82.533649
# 146    away  34.118830  45.734551
# ..      ...        ...        ...
# 279    away  59.851838  72.958391
# 280    away  48.960460  72.629526
# 281    away  46.844855  36.791714
# 282    away  39.963022  42.944915
# 283    away  66.704944  32.015095
#
# [142 rows x 3 columns]
#        dataset          x          y
# 1278  bullseye  51.203891  83.339777
# 1279  bullseye  58.974470  85.499818
# 1280  bullseye  51.872073  85.829738
# 1281  bullseye  48.179931  85.045117
# 1282  bullseye  41.683200  84.017941
# ...        ...        ...        ...
# 1415  bullseye  50.967748  29.679774
# 1416  bullseye  91.191054  46.674343
# 1417  bullseye  55.863768  85.336487
# 1418  bullseye  49.280595  84.048823
# 1419  bullseye  43.368502  84.332177
#
# [142 rows x 3 columns]
#      dataset          x          y
# 1136  circle  55.993030  79.277264
# 1137  circle  50.032254  79.013071
# 1138  circle  51.288459  82.435940
# 1139  circle  51.170537  79.165294
# 1140  circle  44.377915  78.164628
# ...      ...        ...        ...
# 1273  circle  39.921363  19.701850
# 1274  circle  84.794278  55.568650
# 1275  circle  55.662959  83.356480
# 1276  circle  50.492248  78.997532
# 1277  circle  51.467101  79.201845
#
# [142 rows x 3 columns]
#     dataset        x        y
# 0      dino  55.3846  97.1795
# 1      dino  51.5385  96.0256
# 2      dino  46.1538  94.4872
# 3      dino  42.8205  91.4103
# 4      dino  40.7692  88.3333
# ..      ...      ...      ...
# 137    dino  39.4872  25.3846
# 138    dino  91.2821  41.5385
# 139    dino  50.0000  95.7692
# 140    dino  47.9487  95.0000
# 141    dino  44.1026  92.6923
#
# [142 rows x 3 columns]
#      dataset          x          y
# 994     dots  51.147917  90.867412
# 995     dots  50.517126  89.102395
# 996     dots  50.207480  85.460047
# 997     dots  50.069482  83.057670
# 998     dots  50.562846  82.937822
# ...      ...        ...        ...
# 1131    dots  50.533635  17.019581
# 1132    dots  77.500907  50.166986
# 1133    dots  50.691124  87.513960
# 1134    dots  49.990395  83.997357
# 1135    dots  50.127182  82.990750
#
# [142 rows x 3 columns]
#      dataset          x          y
# 284  h_lines  53.366567  90.208030
# 285  h_lines  52.801979  90.088065
# 286  h_lines  47.054130  90.458936
# 287  h_lines  42.448434  89.507700
# 288  h_lines  42.704036  90.442629
# ..       ...        ...        ...
# 421  h_lines  42.224120  30.498037
# 422  h_lines  87.698464  50.489937
# 423  h_lines  52.360331  89.704317
# 424  h_lines  51.406787  89.712139
# 425  h_lines  43.588468  89.745537
#
# [142 rows x 3 columns]
#         dataset          x          y
# 852  high_lines  57.613234  83.905171
# 853  high_lines  51.274392  82.817983
# 854  high_lines  50.753898  76.754129
# 855  high_lines  37.021184  81.954470
# 856  high_lines  42.881755  80.184770
# ..          ...        ...        ...
# 989  high_lines  37.949784  26.521749
# 990  high_lines  86.504391  34.894025
# 991  high_lines  50.815485  78.950839
# 992  high_lines  51.183467  85.128855
# 993  high_lines  40.863855  82.926145
#
# [142 rows x 3 columns]
#          dataset          x          y
# 1562  slant_down  52.872021  97.343223
# 1563  slant_down  59.014144  93.574875
# 1564  slant_down  56.375109  96.305148
# 1565  slant_down  37.839200  94.359443
# 1566  slant_down  39.885373  90.634662
# ...          ...        ...        ...
# 1699  slant_down  39.596501  32.136132
# 1700  slant_down  95.593416  33.234129
# 1701  slant_down  52.772288  99.613472
# 1702  slant_down  53.178614  98.603861
# 1703  slant_down  37.627053  93.060673
#
# [142 rows x 3 columns]
#        dataset          x          y
# 1420  slant_up  47.695201  95.241187
# 1421  slant_up  44.609976  93.075835
# 1422  slant_up  43.856381  94.085872
# 1423  slant_up  41.578929  90.303567
# 1424  slant_up  49.177419  96.610532
# ...        ...        ...        ...
# 1557  slant_up  31.333244  32.538569
# 1558  slant_up  86.401550  38.746933
# 1559  slant_up  47.442112  98.184302
# 1560  slant_up  46.264741  94.116192
# 1561  slant_up  40.163816  87.448672
#
# [142 rows x 3 columns]
#     dataset          x          y
# 710    star  58.213608  91.881892
# 711    star  58.196054  92.214989
# 712    star  58.718231  90.310532
# 713    star  57.278373  89.907607
# 714    star  58.082020  92.008145
# ..      ...        ...        ...
# 847    star  43.722551  19.077328
# 848    star  79.326078  52.900391
# 849    star  56.663974  87.940125
# 850    star  57.821789  90.693167
# 851    star  58.243172  92.104328
#
# [142 rows x 3 columns]
#      dataset          x          y
# 426  v_lines  50.481508  93.222701
# 427  v_lines  50.282406  97.609984
# 428  v_lines  50.186703  99.694680
# 429  v_lines  50.326911  90.022053
# 430  v_lines  50.456207  89.987410
# ..       ...        ...        ...
# 563  v_lines  30.487392  19.779470
# 564  v_lines  89.500180  31.978917
# 565  v_lines  50.410272  98.628369
# 566  v_lines  50.325924  94.994631
# 567  v_lines  50.104031  95.088538
#
# [142 rows x 3 columns]
#          dataset          x          y
# 1704  wide_lines  65.815540  95.588374
# 1705  wide_lines  65.672265  91.933402
# 1706  wide_lines  39.002716  92.261838
# 1707  wide_lines  37.795303  93.532455
# 1708  wide_lines  35.513901  89.599190
# ...          ...        ...        ...
# 1841  wide_lines  33.674442  26.090490
# 1842  wide_lines  75.627255  37.128752
# 1843  wide_lines  40.610125  89.136240
# 1844  wide_lines  39.114366  96.481751
# 1845  wide_lines  34.583829  89.588902
#
# [142 rows x 3 columns]
#      dataset          x          y
# 568  x_shape  38.337757  92.472719
# 569  x_shape  35.751871  94.116768
# 570  x_shape  32.767218  88.518295
# 571  x_shape  33.729607  88.622266
# 572  x_shape  37.238249  83.724928
# ..       ...        ...        ...
# 705  x_shape  34.794594  13.969683
# 706  x_shape  79.221764  22.094591
# 707  x_shape  36.030880  93.121733
# 708  x_shape  34.499558  86.609985
# 709  x_shape  31.106867  89.461635
#
# [142 rows x 3 columns]

# %%
for name, group in df.groupby('dataset'): 
    plt.figure(figsize=(6,4))
    plt.scatter(group['x'], group['y'])
    plt.title(f'Scatter plot for {name}')
    mean_x, var_x, std_x = group['x'].mean(), group['x'].var(), group['x'].std()
    mean_y,var_y, std_y = group['y'].mean(), group['y'].var(), group['y'].std()
    legend_text = (f'Mean x:{mean_x:.2f}')
    plt.legend([legend_text], loc = 'upper left')

# %% [markdown]
# # Use amazing libraries to create such plots

# %% [markdown]
# - Go to https://github.com/stefmolin/data-morph
# - Data Morph transforms an input dataset of 2D points into select shapes, while preserving the summary statistics to a given number of decimal points through simulated annealing.

# %%
# install data-morph-ai (https://github.com/stefmolin/data-morph)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting data-morph-ai
#   Downloading data_morph_ai-0.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: matplotlib>=3.3 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from data-morph-ai) (3.9.2)
# Requirement already satisfied: numpy>=1.20 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from data-morph-ai) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from data-morph-ai) (2.0.3)
# Collecting pytweening>=1.0.5 (from data-morph-ai)
#   Downloading pytweening-1.2.0.tar.gz (171 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=1.10.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from data-morph-ai) (1.13.1)
# Requirement already satisfied: tqdm>=4.64.1 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from data-morph-ai) (4.67.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3->data-morph-ai) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3->data-morph-ai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3->data-morph-ai) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3->data-morph-ai) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3->data-morph-ai) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3->data-morph-ai) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3->data-morph-ai) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3->data-morph-ai) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3->data-morph-ai) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->data-morph-ai) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->data-morph-ai) (2024.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3->data-morph-ai) (3.20.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->data-morph-ai) (1.15.0)
# Downloading data_morph_ai-0.2.0-py3-none-any.whl (104 kB)
# Building wheels for collected packages: pytweening
#   Building wheel for pytweening (setup.py) ... done
#   Created wheel for pytweening: filename=pytweening-1.2.0-py3-none-any.whl size=8026 sha256=e0464271d47d4ab44736f18c305becf056f7c91ad8ad700e6cc3a350b5888637
#   Stored in directory: /Users/adfz088/Library/Caches/pip/wheels/eb/48/3d/ded50b5e7d57738e4bd3ee314e537f4f646328aeaef51d2619
# Successfully built pytweening
# Installing collected packages: pytweening, data-morph-ai
# Successfully installed data-morph-ai-0.2.0 pytweening-1.2.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
# Load dataset using DataLoader.load_dataset('object')

# %%
# available datasets: DataLoader.AVAILABLE_DATASETS
# Out:
# ['bunny', 'cat', 'dino', 'dog', 'music', 'panda', 'Python', 'SDS', 'sheep']

# %%
# available target shape: ShapeFactory.AVAILABLE_SHAPES

from data_morph.shapes.factory import ShapeFactory

ShapeFactory.AVAILABLE_SHAPES
# Out:
# ['bullseye',
#  'circle',
#  'diamond',
#  'dots',
#  'down_parab',
#  'h_lines',
#  'heart',
#  'high_lines',
#  'left_parab',
#  'rectangle',
#  'right_parab',
#  'rings',
#  'scatter',
#  'slant_down',
#  'slant_up',
#  'star',
#  'up_parab',
#  'v_lines',
#  'wide_lines',
#  'x']

# %%
# For morphing purposes, all target shapes are placed/sized based on aspects of the Dataset class.

# %%
# save the result in your local folder
# Out:
# star pattern: 100%|##########| 100000/100000 [01:25<00:00, 1165.83it/s]

# %%
# show the result
# Out:
#              x          y
# 0    89.808858  67.038809
# 1    89.635557  67.360497
# 2    87.157239  65.291245
# 3    87.851091  64.678215
# 4    84.573877  66.393630
# ..         ...        ...
# 684  70.844459  31.049015
# 685  74.890423  25.300529
# 686  76.610645  18.502460
# 687  75.410171  20.604131
# 688  75.841423  20.401655
#
# [689 rows x 2 columns]

# %%
# Plot the graph

# %% [markdown]
# # (Optional) Create your own dataset
# 1) If you just want to plot points on your own, go to  http://robertgrantstats.co.uk/drawmydata.html
#
# 2) If you want to plot points based on a picture that you choose, go to https://www.mobilefish.com/services/record_mouse_coordinates/record_mouse_coordinates.php
